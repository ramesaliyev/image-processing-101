# %% [markdown]
# # Histogram Creation and Equalization

# %% [markdown]
# **Initialization**

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import lib.pgm as libpgm

# %% [markdown]
# **Read PGM**

# %%
#pgm_path = '../assets/pgms/snap.ascii.pgm';
#pgm_path = '../assets/pgms/surf.ascii.pgm';
#pgm_path = '../assets/pgms/totem.ascii.pgm';
pgm_path = '../assets/pgms/screws.ascii.pgm';

pgm = libpgm.read(pgm_path)
libpgm.show(pgm)

# %% [markdown]
# **Calculate and Plot Histogram**

# %%
_, intensity = libpgm.calculate_histogram(pgm);

# %%
import matplotlib.pyplot as plt

plt.hist(range(256), 256, weights=intensity)
plt.show()

# %% [markdown]
# **Do Histogram Equalization**

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(1, 2, 1)
libpgm.show(pgm)        

libpgm.equalize_histogram(pgm)

plt.subplot(1, 2, 2)
libpgm.show(pgm)

# %% [markdown]
# **Recalculate Histogram**

# %%
_, newintensity = libpgm.calculate_histogram(pgm);
plt.subplot(1, 2, 1)
plt.hist(range(256), 256, weights=intensity)
plt.subplot(1, 2, 2)
plt.hist(range(256), 256, weights=newintensity)
plt.show()
